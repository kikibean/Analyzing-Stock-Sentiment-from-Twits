# %% [markdown]
# # Project 6: Analyzing Stock Sentiment from Twits
# ## Instructions
# Each problem consists of a function to implement and instructions on how to implement the function.  The parts of the function that need to be implemented are marked with a `# TODO` comment.
#
# ## Packages
# When you implement the functions, you'll only need to you use the packages you've used in the classroom, like [Pandas](https://pandas.pydata.org/) and [Numpy](http://www.numpy.org/). These packages will be imported for you. We recommend you don't add any import statements, otherwise the grader might not be able to run your code.
#
# ### Load Packages

# %%
import json
import nltk
import os
import random
import re
import torch
import numpy as np
from torch import nn, optim
import torch.nn.functional as F

# %% [markdown]
# ## Introduction
# When deciding the value of a company, it's important to follow the news. For example, a product recall or natural disaster in a company's product chain. You want to be able to turn this information into a signal. Currently, the best tool for the job is a Neural Network.
#
# For this project, you'll use posts from the social media site [StockTwits](https://en.wikipedia.org/wiki/StockTwits). The community on StockTwits is full of investors, traders, and entrepreneurs. Each message posted is called a Twit. This is similar to Twitter's version of a post, called a Tweet. You'll build a model around these twits that generate a sentiment score.
#
# We've collected a bunch of twits, then hand labeled the sentiment of each. To capture the degree of sentiment, we'll use a five-point scale: very negative, negative, neutral, positive, very positive. Each twit is labeled -2 to 2 in steps of 1, from very negative to very positive respectively. You'll build a sentiment analysis model that will learn to assign sentiment to twits on its own, using this labeled data.
#
# The first thing we should to do, is load the data.
#
# ## Import Twits
# ### Load Twits Data
# This JSON file contains a list of objects for each twit in the `'data'` field:
#
# ```
# {'data':
#   {'message_body': 'Neutral twit body text here',
#    'sentiment': 0},
#   {'message_body': 'Happy twit body text here',
#    'sentiment': 1},
#    ...
# }
# ```
#
# The fields represent the following:
#
# * `'message_body'`: The text of the twit.
# * `'sentiment'`: Sentiment score for the twit, ranges from -2 to 2 in steps of 1, with 0 being neutral.
#
#
# To see what the data look like by printing the first 10 twits from the list.

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'twits.json'), 'r') as f:
    twits = json.load(f)

print(twits['data'][:10])
# Out:
# [{'message_body': '$FITB great buy at 26.00...ill wait', 'sentiment': 2, 'timestamp': '2018-07-01T00:00:09Z'}, {'message_body': '@StockTwits $MSFT', 'sentiment': 1, 'timestamp': '2018-07-01T00:00:42Z'}, {'message_body': '#STAAnalystAlert for $TDG : Jefferies Maintains with a rating of Hold setting target price at USD 350.00. Our own verdict is Buy  http://www.stocktargetadvisor.com/toprating', 'sentiment': 2, 'timestamp': '2018-07-01T00:01:24Z'}, {'message_body': '$AMD I heard there’s a guy who knows someone who thinks somebody knows something - on StockTwits.', 'sentiment': 1, 'timestamp': '2018-07-01T00:01:47Z'}, {'message_body': '$AMD reveal yourself!', 'sentiment': 0, 'timestamp': '2018-07-01T00:02:13Z'}, {'message_body': '$AAPL Why the drop? I warren Buffet taking out his position?', 'sentiment': 1, 'timestamp': '2018-07-01T00:03:10Z'}, {'message_body': '$BA bears have 1 reason on 06-29 to pay more attention https://dividendbot.com?s=BA', 'sentiment': -2, 'timestamp': '2018-07-01T00:04:09Z'}, {'message_body': '$BAC ok good we&#39;re not dropping in price over the weekend, lol', 'sentiment': 1, 'timestamp': '2018-07-01T00:04:17Z'}, {'message_body': '$AMAT - Daily Chart, we need to get back to above 50.', 'sentiment': 2, 'timestamp': '2018-07-01T00:08:01Z'}, {'message_body': '$GME 3% drop per week after spike... if no news in 3 months, back to 12s... if BO, then bingo... what is the odds?', 'sentiment': -2, 'timestamp': '2018-07-01T00:09:03Z'}]

# %% [markdown]
# ### Length of Data
# Now let's look at the number of twits in dataset. Print the number of twits below.

# %%
"""print out the number of twits"""

# TODO Implement 

print(len(twits['data']))
# Out:
# 1548010

# %% [markdown]
# ### Split Message Body and Sentiment Score

# %%
messages = [twit['message_body'] for twit in twits['data']]
# Since the sentiment scores are discrete, we'll scale the sentiments to 0 to 4 for use in our network
sentiments = [twit['sentiment'] + 2 for twit in twits['data']]

# %% [markdown]
# ## Preprocessing the Data
# With our data in hand we need to preprocess our text. These twits are collected by filtering on ticker symbols where these are denoted with a leader $ symbol in the twit itself. For example,
#
# `{'message_body': 'RT @google Our annual look at the year in Google blogging (and beyond) http://t.co/sptHOAh8 $GOOG',
#  'sentiment': 0}`
#
# The ticker symbols don't provide information on the sentiment, and they are in every twit, so we should remove them. This twit also has the `@google` username, again not providing sentiment information, so we should also remove it. We also see a URL `http://t.co/sptHOAh8`. Let's remove these too.
#
# The easiest way to remove specific words or phrases is with regex using the `re` module. You can sub out specific patterns with a space:
#
# ```python
# re.sub(pattern, ' ', text)
# ```
# This will substitute a space with anywhere the pattern matches in the text. Later when we tokenize the text, we'll split appropriately on those spaces.

# %% [markdown]
# ### Pre-Processing

# %%
nltk.download('wordnet')


def preprocess(message):
    """
    This function takes a string as input, then performs these operations: 
        - lowercase
        - remove URLs
        - remove ticker symbols 
        - removes punctuation
        - tokenize by splitting the string on whitespace 
        - removes any single character tokens
    
    Parameters
    ----------
        message : The text message to be preprocessed.
        
    Returns
    -------
        tokens: The preprocessed text into tokens.
    """ 
    #TODO: Implement 
    
    # Lowercase the twit message
    text = message.lower()
    
    # Replace URLs with a space in the message
    text = re.sub(r'https?:\/\/.*[\r\n]*', ' ', text, flags=re.MULTILINE)
    
    # Replace ticker symbols with a space. The ticker symbols are any stock symbol that starts with $.
    text = re.sub(r'(\$[a-zA-Z]*)', ' ', text, flags=re.MULTILINE)
    
    # Replace StockTwits usernames with a space. The usernames are any word that starts with @.
    text = re.sub(r'(@[a-zA-Z]*)', ' ', text, flags=re.MULTILINE)

    # Replace everything not a letter with a space
    text = re.sub(r'([^a-zA-Z])', ' ', text, flags=re.MULTILINE)
    
    # Tokenize by splitting the string on whitespace into a list of words
    tokens = text.split()

    # Lemmatize words using the WordNetLemmatizer. You can ignore any word that is not longer than one character.
    wnl = nltk.stem.WordNetLemmatizer()
    tokens = [wnl.lemmatize(token) for token in tokens if len(token)>1]
    
    return tokens
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %% [markdown]
# ### Preprocess All the Twits
# Now we can preprocess each of the twits in our dataset. Apply the function `preprocess` to all the twit messages.

# %%
# TODO Implement

tokenized = [preprocess(message) for message in messages]

# %% [markdown]
# ### Bag of Words
# Now with all of our messages tokenized, we want to create a vocabulary and count up how often each word appears in our entire corpus. Use the [`Counter`](https://docs.python.org/3.1/library/collections.html#collections.Counter) function to count up all the tokens.

# %%
from collections import Counter


"""
Create a vocabulary by using Bag of words
"""

# TODO: Implement 

bow = Counter(word for sentence in tokenized for word in sentence)
# Out:
# Counter({'great': 17516,
#          'buy': 76026,
#          'at': 138206,
#          'ill': 882,
#          'wait': 11356,
#          'staanalystalert': 4072,
#          'for': 272841,
#          'jefferies': 1056,
#          'maintains': 902,
#          'with': 68690,
#          'rating': 15423,
#          'of': 210919,
#          'hold': 22131,
#          'setting': 3886,
#          'target': 16420,
#          'price': 37016,
#          'usd': 2954,
#          'our': 12187,
#          'own': 8954,
#          'verdict': 3736,
#          'is': 283874,
#          'heard': 1352,
#          'there': 25583,
#          'guy': 13406,
#          'who': 17840,
#          'know': 19902,
#          'someone': 5187,
#          'think': 24241,
#          'somebody': 1099,
#          'something': 5996,
#          'on': 241389,
#          'stocktwits': 1437,
#          'reveal': 195,
#          'yourself': 1203,
#          'why': 21636,
#          'the': 397917,
#          'drop': 17771,
#          'warren': 1013,
#          'buffet': 1298,
#          'taking': 6407,
#          'out': 56206,
#          'his': 6249,
#          'position': 11744,
#          'bear': 33541,
#          'have': 52746,
#          'reason': 7769,
#          'to': 378596,
#          'pay': 7593,
#          'more': 55239,
#          'attention': 3522,
#          'ok': 4560,
#          'good': 44012,
#          'we': 64552,
#          're': 13168,
#          'not': 68134,
#          'dropping': 2265,
#          'in': 204412,
#          'over': 32639,
#          'weekend': 3555,
#          'lol': 30906,
#          'daily': 13954,
#          'chart': 15974,
#          'need': 21496,
#          'get': 46542,
#          'back': 43034,
#          'above': 17847,
#          'per': 16561,
#          'week': 44007,
#          'after': 34349,
#          'spike': 2202,
#          'if': 58894,
#          'no': 40348,
#          'news': 19585,
#          'month': 16884,
#          'bo': 609,
#          'then': 20952,
#          'bingo': 181,
#          'what': 79074,
#          'odds': 392,
#          'strong': 17187,
#          'short': 86558,
#          'ratio': 7663,
#          'and': 208194,
#          'float': 4651,
#          'squeezing': 228,
#          'perfect': 1984,
#          'place': 2843,
#          'an': 22464,
#          'option': 20505,
#          'straddle': 2232,
#          'near': 5818,
#          'supporting': 267,
#          'trend': 8023,
#          'start': 8873,
#          'new': 46023,
#          'monday': 7365,
#          'expect': 10351,
#          'volume': 43632,
#          'across': 780,
#          'key': 8461,
#          'company': 22128,
#          'various': 84,
#          'sector': 5035,
#          'breakout': 6603,
#          'strategy': 1620,
#          'current': 6178,
#          'portfolio': 2461,
#          'bull': 27169,
#          'catalyst': 1284,
#          'continuing': 351,
#          'this': 203027,
#          'uptrend': 1688,
#          'pill': 196,
#          'pack': 191,
#          'amazon': 10770,
#          'prime': 1821,
#          'day': 67304,
#          'earnings': 52868,
#          'test': 4024,
#          'break': 17088,
#          'soon': 16138,
#          'ha': 44198,
#          'moved': 3367,
#          'check': 5074,
#          'movement': 2866,
#          'peer': 3176,
#          'mkm': 164,
#          'partner': 1164,
#          'set': 5755,
#          'it': 193166,
#          'too': 18950,
#          'early': 4766,
#          'tell': 4590,
#          'going': 47824,
#          'happen': 4261,
#          'even': 15792,
#          'about': 27491,
#          'raisinf': 1,
#          'output': 107,
#          'still': 35166,
#          'so': 45831,
#          'many': 9442,
#          'financially': 570,
#          'healthy': 1804,
#          'problem': 2745,
#          'meeting': 1001,
#          'obligation': 670,
#          'bullish': 25165,
#          'stock': 74732,
#          'watch': 14666,
#          'setup': 8105,
#          'timeframes': 39,
#          'just': 73100,
#          'high': 28057,
#          'alert': 12203,
#          'next': 46729,
#          'gt': 9348,
#          'breakdown': 1102,
#          'much': 16579,
#          'better': 13765,
#          'than': 29094,
#          'industry': 7775,
#          'average': 9252,
#          'miss': 6970,
#          'these': 14082,
#          'confirms': 411,
#          'you': 94104,
#          'will': 128013,
#          'see': 44253,
#          'violent': 147,
#          'move': 22381,
#          'downward': 831,
#          'my': 51283,
#          'base': 1465,
#          'gap': 9758,
#          'ma': 5067,
#          'cabot': 106,
#          'weekly': 7161,
#          'video': 2781,
#          'quot': 39973,
#          'resilient': 137,
#          'growth': 36074,
#          'when': 30015,
#          'wa': 55211,
#          'kid': 1692,
#          'froend': 1,
#          'told': 3841,
#          'me': 25845,
#          'moon': 2173,
#          'made': 7802,
#          'cheese': 116,
#          'percent': 6309,
#          'rank': 5334,
#          'th': 6552,
#          'percentile': 1399,
#          'thank': 4121,
#          'don': 25395,
#          'feel': 5986,
#          'or': 37453,
#          'do': 24560,
#          'well': 16525,
#          'they': 56217,
#          'already': 9649,
#          'during': 2560,
#          'youtube': 593,
#          'interview': 613,
#          'mitch': 62,
#          'couldn': 1252,
#          'remember': 4815,
#          'single': 2166,
#          'movie': 875,
#          'he': 11534,
#          'watched': 339,
#          'all': 59768,
#          'year': 34246,
#          'except': 1129,
#          'star': 2383,
#          'war': 4942,
#          'black': 1215,
#          'panther': 27,
#          'clothes': 114,
#          'downgrade': 4252,
#          'sale': 27032,
#          'interest': 11774,
#          'return': 7075,
#          'equity': 3275,
#          'although': 1869,
#          'market': 53391,
#          'up': 121014,
#          'doing': 5511,
#          'advanced': 991,
#          'a': 46101,
#          'info': 3807,
#          'july': 3139,
#          'be': 89060,
#          'most': 8208,
#          'normal': 1624,
#          'friday': 11148,
#          'contract': 14248,
#          'call': 67867,
#          'put': 36947,
#          'third': 1591,
#          'design': 607,
#          'win': 5856,
#          'timing': 656,
#          'match': 406,
#          'probably': 5048,
#          'arm': 305,
#          'alcohol': 72,
#          'tobacco': 149,
#          'firearm': 3,
#          'president': 2846,
#          'trump': 11784,
#          'tweet': 1395,
#          'spoke': 172,
#          'king': 1334,
#          'salman': 4,
#          'saudi': 756,
#          'arabia': 149,
#          'explained': 113,
#          'him': 2083,
#          'that': 89248,
#          'because': 7866,
#          'turmoil': 129,
#          'amp': 35535,
#          'today': 76118,
#          'insight': 8185,
#          'intc': 1982,
#          'mama': 166,
#          'said': 9385,
#          'ice': 372,
#          'cream': 115,
#          'finish': 1165,
#          'due': 3689,
#          'dil': 3,
#          'noticed': 365,
#          'last': 38572,
#          'jedi': 176,
#          'stream': 603,
#          'love': 10326,
#          'here': 74909,
#          'go': 52712,
#          'leave': 1292,
#          'view': 5115,
#          'look': 31143,
#          'ema': 1388,
#          'held': 2809,
#          'stochastics': 73,
#          'turning': 1167,
#          'spy': 2132,
#          'qqq': 655,
#          'opposite': 876,
#          'forward': 3410,
#          'pe': 4550,
#          'valuation': 4513,
#          'can': 44157,
#          'described': 346,
#          'cheap': 7812,
#          'saber': 13,
#          'capital': 2913,
#          'presentation': 624,
#          'common': 1428,
#          'denominator': 9,
#          'tencent': 164,
#          'facebook': 8075,
#          'google': 3202,
#          'how': 24403,
#          'one': 27351,
#          'performing': 858,
#          'crude': 482,
#          'petroleum': 249,
#          'natural': 517,
#          'gas': 1493,
#          'pu': 49,
#          'simply': 635,
#          'havent': 214,
#          'lost': 4547,
#          'any': 14375,
#          'brown': 256,
#          'run': 15772,
#          'tech': 9851,
#          'mf': 308,
#          'are': 101209,
#          'educated': 114,
#          'their': 24178,
#          'shit': 6405,
#          'every': 8929,
#          'former': 435,
#          'global': 2500,
#          'manufacturing': 362,
#          'pfizer': 452,
#          'independent': 150,
#          'director': 5452,
#          'nat': 135,
#          'ricciardi': 4,
#          'may': 10932,
#          'safest': 153,
#          'special': 625,
#          'limited': 552,
#          'offer': 1523,
#          'june': 1299,
#          'tradenet': 5,
#          'offering': 643,
#          'discount': 1451,
#          'intro': 49,
#          'program': 1007,
#          'below': 11227,
#          'financials': 988,
#          'summary': 462,
#          'jeff': 685,
#          'gundlach': 41,
#          'sohn': 23,
#          'long': 32468,
#          'thesis': 1002,
#          'energy': 2788,
#          'low': 22995,
#          'peg': 546,
#          'which': 8183,
#          'compensates': 296,
#          'indicates': 1981,
#          'rather': 2366,
#          'pres': 350,
#          'coming': 18884,
#          'seems': 5378,
#          'support': 16869,
#          'under': 8989,
#          'likely': 3642,
#          'bullshit': 873,
#          'worthless': 1025,
#          'mean': 6150,
#          'fucking': 2380,
#          'nothing': 7007,
#          'macau': 279,
#          'usa': 1070,
#          'take': 17607,
#          'let': 26891,
#          'where': 12403,
#          'right': 18739,
#          'now': 57414,
#          'ugly': 1840,
#          'without': 2337,
#          'clear': 2618,
#          'level': 9352,
#          'term': 17559,
#          'bearish': 11431,
#          'll': 13143,
#          'previously': 2033,
#          'mo': 893,
#          'followed': 972,
#          'by': 53772,
#          'end': 15755,
#          'another': 13984,
#          'runup': 188,
#          'dropped': 2953,
#          'smart': 3319,
#          'money': 24867,
#          'betting': 854,
#          'deal': 6708,
#          'update': 20552,
#          'technical': 11296,
#          'bad': 13213,
#          'doe': 11162,
#          'present': 2422,
#          'nice': 16783,
#          'opportunity': 5855,
#          'completely': 1017,
#          'scale': 382,
#          'time': 39264,
#          'gobble': 106,
#          'play': 9228,
#          'aka': 335,
#          'favorite': 867,
#          'them': 11028,
#          'iddy': 1,
#          'bitty': 10,
#          'kiddy': 33,
#          'hand': 3728,
#          'awesome': 1842,
#          'concerned': 540,
#          'eow': 2111,
#          'might': 8743,
#          'wk': 1304,
#          'throwback': 59,
#          'u': 13254,
#          'advisor': 220,
#          'upgrade': 6829,
#          'shorties': 808,
#          'dreaming': 232,
#          'depression': 137,
#          'somethin': 27,
#          'loll': 47,
#          'updated': 811,
#          'hormel': 115,
#          'food': 1479,
#          'dividend': 8452,
#          'analysis': 3369,
#          'consumer': 1979,
#          'defensive': 282,
#          'intel': 7904,
#          'profitability': 1887,
#          'safety': 1126,
#          'score': 2651,
#          'technology': 3110,
#          'both': 6224,
#          'positive': 9031,
#          'looking': 17881,
#          'mad': 1239,
#          'report': 55239,
#          'block': 9924,
#          'person': 698,
#          'spam': 271,
#          'should': 23974,
#          'open': 20682,
#          'projection': 279,
#          'thats': 2244,
#          'true': 2120,
#          'prefer': 361,
#          'from': 62101,
#          'turd': 1080,
#          'wal': 125,
#          'mart': 147,
#          'aristocrat': 302,
#          'valueinvesting': 53,
#          'dvb': 22,
#          'aaamp': 27,
#          'marriage': 37,
#          'bank': 7530,
#          'account': 2794,
#          'dm': 57,
#          'won': 5411,
#          'stop': 12777,
#          'posting': 1286,
#          'holding': 14787,
#          'big': 27578,
#          'calm': 906,
#          'down': 68931,
#          'luck': 3406,
#          'chase': 1361,
#          'continues': 2437,
#          'hopefully': 2614,
#          'catch': 1746,
#          'before': 25790,
#          'lisa': 3070,
#          'announces': 3372,
#          'rd': 1383,
#          'permamently': 1,
#          'turned': 1356,
#          'off': 21225,
#          'trading': 20811,
#          'maybe': 7804,
#          'altogether': 25,
#          'manipulation': 2479,
#          'very': 19972,
#          'rich': 1615,
#          'make': 19897,
#          'poor': 1884,
#          'fuk': 227,
#          'almost': 5574,
#          'pct': 747,
#          'buyback': 5098,
#          'got': 16193,
#          'share': 48641,
#          'though': 4110,
#          'drip': 324,
#          'dumped': 1063,
#          'obv': 181,
#          'but': 53408,
#          'jeez': 339,
#          'bit': 4441,
#          'done': 5472,
#          'bounce': 11611,
#          'heikin': 10,
#          'ashi': 12,
#          'candle': 3263,
#          'confirmation': 737,
#          'liking': 418,
#          'wife': 650,
#          'tree': 513,
#          'fiddy': 32,
#          'sure': 8282,
#          'piggy': 270,
#          'lot': 10005,
#          'coin': 405,
#          'spend': 801,
#          'candy': 113,
#          'microsoft': 1956,
#          'investor': 8417,
#          'aren': 1685,
#          'happy': 4350,
#          'royal': 431,
#          'canada': 1344,
#          'reiterates': 1333,
#          'outperform': 1850,
#          'loop': 286,
#          'raise': 5763,
#          'never': 9005,
#          'been': 19800,
#          'wrong': 5593,
#          'miracle': 310,
#          'period': 1159,
#          'bollinger': 1344,
#          'band': 1516,
#          'dare': 353,
#          'say': 16245,
#          'didn': 5916,
#          'guilty': 97,
#          'fudge': 66,
#          'hardly': 254,
#          'ever': 5649,
#          'informative': 33,
#          'comment': 2083,
#          'page': 562,
#          'broken': 1590,
#          'giving': 1775,
#          'endless': 233,
#          'buffering': 4,
#          'icon': 94,
#          'give': 7665,
#          'viral': 18,
#          'walk': 1116,
#          'away': 4793,
#          'highlight': 248,
#          'growing': 2224,
#          'democrat': 276,
#          'leaving': 871,
#          'party': 1706,
#          'epoch': 2,
#          'robert': 975,
#          'baird': 649,
#          'neutral': 3506,
#          'weed': 715,
#          'other': 8459,
#          'drug': 1311,
#          'guess': 5920,
#          'reasonable': 609,
#          'nike': 3991,
#          'winning': 2103,
#          'click': 857,
#          'booking': 823,
#          'app': 5939,
#          'native': 19,
#          'seamless': 10,
#          'lovalized': 1,
#          'transactable': 1,
#          'ap': 80,
#          'vitiello': 1,
#          'tapped': 126,
#          'acting': 770,
#          'via': 12420,
#          'reach': 1960,
#          'iconic': 62,
#          'brand': 1967,
#          'built': 443,
#          'mobile': 963,
#          'show': 9555,
#          'morning': 11333,
#          'heading': 2782,
#          'ath': 3137,
#          'acquisition': 1764,
#          'total': 6060,
#          'past': 8297,
#          'exit': 1468,
#          'zone': 1588,
#          'fantastic': 574,
#          'read': 3768,
#          'oil': 4742,
#          'tighten': 205,
#          'bbl': 151,
#          'getting': 12169,
#          'closer': 974,
#          'greatest': 421,
#          'yearly': 1240,
#          'performance': 2084,
#          'did': 12596,
#          'champion': 159,
#          'cashflow': 75,
#          'highyield': 23,
#          'telecommunication': 7,
#          'pretty': 4434,
#          'risky': 710,
#          'gamble': 831,
#          'either': 3231,
#          'plummet': 326,
#          'rally': 6195,
#          'stronger': 865,
#          'apple': 12769,
#          'talking': 2689,
#          'referring': 107,
#          'intelsat': 5,
#          'punish': 128,
#          'seller': 3015,
#          'warehouse': 87,
#          'sense': 2198,
#          'old': 3801,
#          'gather': 129,
#          'dust': 433,
#          'pc': 611,
#          'gamers': 212,
#          'crypto': 1732,
#          'miner': 169,
#          'gpu': 1288,
#          'enthusiast': 27,
#          'waiting': 7236,
#          'two': 5496,
#          'only': 18975,
#          'medium': 3266,
#          'decent': 2927,
#          'pattern': 6525,
#          'five': 740,
#          'baba': 545,
#          'ahhhhhhhhhhhhhhhhhhhhh': 1,
#          'raytheon': 176,
#          'industrials': 308,
#          'military': 308,
#          'trending': 1954,
#          'riiiiiiiiiich': 1,
#          'sooooon': 11,
#          'buuuuls': 1,
#          'looooove': 4,
#          'drunk': 207,
#          'doesn': 6267,
#          'through': 6151,
#          'gapping': 285,
#          'warbey': 1,
#          'parker': 205,
#          'prep': 102,
#          'glass': 295,
#          'seen': 3828,
#          'focus': 1053,
#          'fashion': 211,
#          'wrt': 16,
#          'wearable': 106,
#          'like': 51777,
#          'sbux': 224,
#          'paying': 1523,
#          'full': 2977,
#          'sex': 169,
#          'change': 5173,
#          'employee': 1101,
#          'hit': 12510,
#          'bottom': 9686,
#          'line': 7046,
#          'recap': 1342,
#          'since': 22599,
#          'post': 7828,
#          'trade': 49537,
#          'included': 374,
#          'hsy': 25,
#          'uri': 46,
#          'sonc': 11,
#          'dri': 41,
#          'kmx': 32,
#          'wynn': 506,
#          'akam': 48,
#          'enterprise': 1329,
#          'value': 5669,
#          'v': 5366,
#          'cap': 4053,
#          'difference': 602,
#          'actual': 649,
#          'asset': 1903,
#          'spread': 2451,
#          'way': 16450,
#          'undervalued': 2514,
#          'million': 6380,
#          'added': 5555,
#          'dont': 6251,
#          'become': 1579,
#          'such': 2912,
#          'monopoly': 326,
#          'dipping': 299,
#          'into': 17265,
#          'everything': 4289,
#          'airline': 942,
#          'possibility': 467,
#          'loss': 7730,
#          'suggested': 321,
#          'chartmill': 199,
#          'analyzer': 520,
#          'resistance': 6962,
#          'len': 54,
#          'reversal': 4917,
#          'progress': 563,
#          've': 6734,
#          'recently': 824,
#          'closed': 3350,
#          'list': 3061,
#          'bought': 19128,
#          'same': 12064,
#          'used': 1739,
#          'according': 2030,
#          'data': 9715,
#          'reported': 14150,
#          'finra': 2763,
#          'clocked': 707,
#          'official': 471,
#          'came': 1630,
#          'saying': 4009,
#          'agree': 1536,
#          'resume': 516,
#          'cover': 5876,
#          'penis': 47,
#          'putang': 1,
#          'front': 568,
#          'leg': 2239,
#          'would': 22369,
#          'some': 30395,
#          'am': 14328,
#          'watching': 5552,
#          'wonder': 2992,
#          'valued': 1624,
#          'inning': 69,
#          'higher': 25446,
#          'also': 7888,
#          'shorted': 2971,
#          'consolidation': 2029,
#          'cautious': 516,
#          'stunned': 42,
#          'deeply': 90,
#          'disappointed': 457,
#          'close': 29506,
#          'ending': 1212,
#          'killed': 1221,
#          'best': 9957,
#          'february': 375,
#          'funny': 2510,
#          'thing': 12589,
#          'similar': 1131,
#          'story': 2643,
#          'different': 1553,
#          'crab': 39,
#          'measured': 489,
#          'divergence': 774,
#          'really': 11266,
#          'momentum': 3389,
#          'starting': 3241,
#          'shi': 59,
#          'venture': 299,
#          'tariff': 8042,
#          'increase': 3976,
#          'profit': 16140,
#          'recession': 1042,
#          'come': 18448,
#          'keep': 14930,
#          'buying': 23793,
#          'pure': 932,
#          'beanscreen': 2,
#          'min': 5721,
#          'indicating': 431,
#          'accumulation': 731,
#          'eod': 5176,
#          'could': 16182,
#          'pop': 7339,
#          'heavy': 1715,
#          'apog': 7,
#          'acn': 46,
#          'camp': 62,
#          'gi': 61,
#          'payx': 23,
#          'fdx': 113,
#          'goo': 179,
#          'squeeze': 5681,
#          'pullback': 4431,
#          'upside': 5160,
#          'nvda': 3191,
#          'safe': 1990,
#          'yield': 2479,
#          'div': 2202,
#          'adding': 2948,
#          'gladly': 91,
#          'irrationality': 24,
#          'reign': 40,
#          'possible': 4170,
#          'excess': 65,
#          'gain': 11670,
#          'welcome': 1337,
#          'gl': 3042,
#          'seeing': 2560,
#          'jumping': 707,
#          'joy': 272,
#          'least': 5512,
#          'given': 2984,
#          'action': 6831,
#          'bouncing': 946,
#          'continuation': 584,
#          'hopeful': 168,
#          'science': 333,
#          'officially': 540,
#          'became': 318,
#          'major': 3724,
#          'university': 70,
#          'ai': 1729,
#          'brainers': 5,
#          'era': 294,
#          'second': 2987,
#          'minute': 5052,
#          'rule': 2003,
#          'applies': 83,
#          'zbra': 6,
#          'six': 557,
#          'fc': 23,
#          'gbx': 4,
#          'fds': 31,
#          'avav': 9,
#          'killing': 1662,
#          'tax': 2248,
#          'cut': 4881,
#          'idea': 3793,
#          'haven': 1827,
#          'posted': 4210,
#          'while': 7215,
#          'omg': 1696,
#          'toy': 360,
#          'land': 607,
#          'amazing': 2985,
#          'contributed': 38,
#          'ytd': 1169,
#          'popular': 406,
#          'word': 2036,
#          'buyin': 130,
#          'those': 9835,
#          'dip': 17705,
#          'haha': 2075,
#          'makin': 55,
#          'rain': 218,
#          'white': 922,
#          'house': 1697,
#          'quality': 1460,
#          'moment': 2630,
#          'doubt': 1730,
#          'production': 931,
#          'eps': 33290,
#          'constellation': 326,
#          'disney': 1297,
#          'clinch': 9,
#          'acquire': 711,
#          'fox': 768,
#          'group': 4412,
#          'counter': 250,
#          'aggregate': 761,
#          'southwest': 152,
#          'flight': 326,
#          'dallas': 44,
#          'delta': 420,
#          'spat': 52,
#          'california': 290,
#          'netflix': 5077,
#          'inc': 6991,
#          'nflx': 3235,
#          'versus': 925,
#          'fb': 7792,
#          'starbucks': 586,
#          'using': 2143,
#          'iex': 2187,
#          'calculate': 207,
#          'shorters': 271,
#          'emergence': 1,
#          'bankruptcy': 1423,
#          'emergency': 85,
#          'zwj': 6,
#          'investment': 4326,
#          'counsel': 371,
#          'lower': 16035,
#          'stake': 1022,
#          'unitedhealth': 172,
#          'unh': 107,
#          'tyzen': 1,
#          'vega': 668,
#          'laptop': 367,
#          'investing': 1658,
#          'annuity': 17,
#          'yr': 2877,
#          'bond': 1247,
#          'continue': 3684,
#          'add': 6063,
#          'unsure': 70,
#          'country': 1027,
#          'amd': 22432,
#          'ryzen': 999,
#          'gettin': 151,
#          'blasted': 69,
#          'cgnx': 6,
#          'cx': 40,
#          'aaoi': 53,
#          'aa': 76,
#          'amswa': 1,
#          'yy': 20,
#          'snx': 8,
#          'shark': 218,
#          'definitely': 1897,
#          'august': 2663,
#          'g': 1227,
#          'point': 8686,
#          'huge': 9290,
#          'closing': 3852,
#          'scalp': 1290,
#          'giant': 1401,
#          'fermenting': 1,
#          'marked': 88,
#          'compared': 2773,
#          'book': 1958,
#          'cheaply': 737,
#          'quite': 3391,
#          'job': 3557,
#          'started': 5086,
#          'clearly': 1055,
#          'cup': 1973,
#          'holder': 2396,
#          'inverse': 502,
#          'confidence': 768,
#          'debt': 3063,
#          'sell': 35117,
#          'interesting': 3512,
#          'frame': 434,
#          'trader': 4882,
#          'meanwhile': 505,
#          'galaxy': 120,
#          'far': 5514,
#          'broadening': 29,
#          'wedge': 1253,
#          'descending': 312,
#          'large': 6257,
#          'im': 5075,
#          'pt': 16259,
#          'three': 1622,
#          'falling': 3276,
#          'peak': 1896,
#          'fourth': 250,
#          'everyone': 8347,
#          'coke': 279,
#          'smile': 212,
#          'thanks': 5661,
#          'selling': 17590,
#          'prove': 451,
#          'terrible': 936,
#          'error': 161,
#          'article': 2449,
#          'hint': 345,
#          'sogou': 11,
#          'finger': 681,
#          'crossed': 1343,
#          'triple': 1164,
#          'top': 14081,
#          'bro': 614,
#          'work': 5131,
#          'delete': 293,
#          'blue': 1644,
#          'arrow': 117,
#          'your': 25467,
#          'delusion': 82,
#          'overbought': 1690,
#          'changing': 488,
#          'mr': 1178,
#          'yo': 893,
#          'hi': 794,
#          'bed': 715,
#          'night': 2764,
#          'prepared': 346,
#          'policy': 364,
#          'penalizing': 2,
#          ...})

# %% [markdown]
# ### Frequency of Words Appearing in Message
# With our vocabulary, now we'll remove some of the most common words such as 'the', 'and', 'it', etc. These words don't contribute to identifying sentiment and are really common, resulting in a lot of noise in our input. If we can filter these out, then our network should have an easier time learning.
#
# We also want to remove really rare words that show up in a only a few twits. Here you'll want to divide the count of each word by the number of messages. Then remove words that only appear in some small fraction of the messages.

# %%
"""
Set the following variables:
    freqs
    low_cutoff
    high_cutoff
    K_most_common
"""

# TODO Implement 

# Dictionart that contains the Frequency of words appearing in messages.
# The key is the token and the value is the frequency of that word in the corpus.
totals= sum(bow.values())
freqs = {word:count/totals for word,count in bow.items()}

# Float that is the frequency cutoff. Drop words with a frequency that is lower or equal to this number.
low_cutoff = 1e-5

# Integer that is the cut off for most common words. Drop words that are the `high_cutoff` most common words.
high_cutoff = 10

# The k most common words in the corpus. Use `high_cutoff` as the k.
K_most_common = bow.most_common(high_cutoff)


filtered_words = [word for word in freqs if (freqs[word] > low_cutoff and word not in K_most_common)]
print(K_most_common)
len(filtered_words)
# Out:
# [('the', 397917), ('to', 378596), ('is', 283874), ('for', 272841), ('on', 241389), ('of', 210919), ('and', 208194), ('in', 204412), ('this', 203027), ('it', 193166)]
# 4537

# %% [markdown]
# ### Updating Vocabulary by Removing Filtered Words
# Let's creat three variables that will help with our vocabulary.

# %%
"""
Set the following variables:
    vocab
    id2vocab
    filtered
"""

#TODO Implement

# A dictionary for the `filtered_words`. The key is the word and value is an id that represents the word. 
vocab = {word: ii for ii, word in enumerate(filtered_words)}
# Reverse of the `vocab` dictionary. The key is word id and value is the word. 
id2vocab = {value:key for key,value in vocab.items()}
# tokenized with the words not in `filtered_words` removed.
filtered = [[word for word in sentence if word in vocab] for sentence in tokenized]

# %% [markdown]
# ### Balancing the classes
# Let's do a few last pre-processing steps. If we look at how our twits are labeled, we'll find that 50% of them are neutral. This means that our network will be 50% accurate just by guessing 0 every single time. To help our network learn appropriately, we'll want to balance our classes.
# That is, make sure each of our different sentiment scores show up roughly as frequently in the data.
#
# What we can do here is go through each of our examples and randomly drop twits with neutral sentiment. What should be the probability we drop these twits if we want to get around 20% neutral twits starting at 50% neutral? We should also take this opportunity to remove messages with length 0.

# %%
balanced = {'messages': [], 'sentiments':[]}

n_neutral = sum(1 for each in sentiments if each == 2)
N_examples = len(sentiments)
keep_prob = (N_examples - n_neutral)/4/n_neutral

for idx, sentiment in enumerate(sentiments):
    message = filtered[idx]
    if len(message) == 0:
        # skip this message because it has length zero
        continue
    elif sentiment != 2 or random.random() < keep_prob:
        balanced['messages'].append(message)
        balanced['sentiments'].append(sentiment)

# %% [markdown]
# If you did it correctly, you should see the following result

# %%
n_neutral = sum(1 for each in balanced['sentiments'] if each == 2)
N_examples = len(balanced['sentiments'])
n_neutral/N_examples
# Out:
# 0.19397250176958192

# %% [markdown]
# Finally let's convert our tokens into integer ids which we can pass to the network.

# %%
token_ids = [[vocab[word] for word in message] for message in balanced['messages']]
sentiments = balanced['sentiments']

# %% [markdown]
# ## Neural Network
# Now we have our vocabulary which means we can transform our tokens into ids, which are then passed to our network. So, let's define the network now!
#
# Here is a nice diagram showing the network we'd like to build:
#
# #### Embed -> RNN -> Dense -> Softmax
# ### Implement the text classifier
# Before we build text classifier, if you remember from the other network that you built in  "Sentiment Analysis with an RNN"  exercise  - which there, the network called " SentimentRNN", here we named it "TextClassifer" - consists of three main parts: 1) init function `__init__` 2) forward pass `forward`  3) hidden state `init_hidden`.
#
# This network is pretty similar to the network you built expect in the  `forward` pass, we use softmax instead of sigmoid. The reason we are not using sigmoid is that the output of NN is not a binary. In our network, sentiment scores have 5 possible outcomes. We are looking for an outcome with the highest probability thus softmax is a better choice.

# %%
class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_size, lstm_size, output_size, lstm_layers=1, dropout=0.1):
        """
        Initialize the model by setting up the layers.
        
        Parameters
        ----------
            vocab_size : The vocabulary size.
            embed_size : The embedding layer size.
            lstm_size : The LSTM layer size.
            output_size : The output size.
            lstm_layers : The number of LSTM layers.
            dropout : The dropout probability.
        """
        
        super().__init__()
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.lstm_size = lstm_size
        self.output_size = output_size
        self.lstm_layers = lstm_layers
        self.dropout = dropout
        
        # TODO Implement

        # Setup embedding layer
        self.embedding = nn.Embedding(vocab_size, embed_size, padding_idx=0)
        
        # Setup additional layers
        self.lstm = nn.LSTM(embed_size, lstm_size, lstm_layers, dropout=dropout, batch_first=False)
        self.dense = nn.Linear(in_features=lstm_size, out_features=output_size)
        self.softmax = nn.LogSoftmax(dim=1)


    def init_hidden(self, batch_size):
        """ 
        Initializes hidden state
        
        Parameters
        ----------
            batch_size : The size of batches.
        
        Returns
        -------
            hidden_state
            
        """
        
        # TODO Implement 
        
        # Create two new tensors with sizes n_layers x batch_size x hidden_dim,
        # initialized to zero, for hidden state and cell state of LSTM
        
        weight = next(self.parameters()).data
        
        hidden_state = weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_() 
        cell_state = weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_()
        
        return (hidden_state, cell_state)


    def forward(self, nn_input, hidden_state):
        """
        Perform a forward pass of our model on nn_input.
        
        Parameters
        ----------
            nn_input : The batch of input to the NN.
            hidden_state : The LSTM hidden state.

        Returns
        -------
            logps: log softmax output
            hidden_state: The new hidden state.

        """
        
        # TODO Implement 
        batch_size = nn_input.size(0)
        
        # embeddings and lstm_out
        x = nn_input.long()
        embeds = self.embedding(x)
        lstm_out, hidden = self.lstm(embeds, hidden_state)        
        
        # stack up lstm outputs
        lstm_out = lstm_out[-1,:,:]
        
        # fully-connected layer
        dense_out = self.dense(lstm_out)
        
        # softmax
        softmax_out = self.softmax(dense_out)
        
        return softmax_out, hidden_state

# %% [markdown]
# ### View Model

# %%
model = TextClassifier(len(vocab), 10, 6, 5, dropout=0.1, lstm_layers=2)
model.embedding.weight.data.uniform_(-1, 1)
input = torch.randint(0, 1000, (5, 4), dtype=torch.int64)
hidden = model.init_hidden(4)

logps, _ = model.forward(input, hidden)
print(logps)
# Out:
# tensor([[-1.2665, -1.7510, -1.6790, -1.6611, -1.7832],
#         [-1.2660, -1.7404, -1.6840, -1.6734, -1.7757],
#         [-1.2664, -1.7425, -1.6835, -1.6703, -1.7770],
#         [-1.2622, -1.7568, -1.6795, -1.6585, -1.7868]])

# %% [markdown]
# ## Training
# ### DataLoaders and Batching
# Now we should build a generator that we can use to loop through our data. It'll be more efficient if we can pass our sequences in as batches. Our input tensors should look like `(sequence_length, batch_size)`. So if our sequences are 40 tokens long and we pass in 25 sequences, then we'd have an input size of `(40, 25)`.
#
# If we set our sequence length to 40, what do we do with messages that are more or less than 40 tokens? For messages with fewer than 40 tokens, we will pad the empty spots with zeros. We should be sure to **left** pad so that the RNN starts from nothing before going through the data. If the message has 20 tokens, then the first 20 spots of our 40 long sequence will be 0. If a message has more than 40 tokens, we'll just keep the first 40 tokens.

# %%
def dataloader(messages, labels, sequence_length=30, batch_size=32, shuffle=False):
    """ 
    Build a dataloader.
    """
    if shuffle:
        indices = list(range(len(messages)))
        random.shuffle(indices)
        messages = [messages[idx] for idx in indices]
        labels = [labels[idx] for idx in indices]

    total_sequences = len(messages)

    for ii in range(0, total_sequences, batch_size):
        batch_messages = messages[ii: ii+batch_size]
        
        # First initialize a tensor of all zeros
        batch = torch.zeros((sequence_length, len(batch_messages)), dtype=torch.int64)
        for batch_num, tokens in enumerate(batch_messages):
            token_tensor = torch.tensor(tokens)
            # Left pad!
            start_idx = max(sequence_length - len(token_tensor), 0)
            batch[start_idx:, batch_num] = token_tensor[:sequence_length]
        
        label_tensor = torch.tensor(labels[ii: ii+len(batch_messages)])
        
        yield batch, label_tensor

# %% [markdown]
# ### Training and  Validation
# With our data in nice shape, we'll split it into training and validation sets.

# %%
"""
Split data into training and validation datasets. Use an appropriate split size.
The features are the `token_ids` and the labels are the `sentiments`.
"""   

# TODO Implement 

def train_test_split(dataset, split=0.70):
    split_idx = int(len(dataset) * split)
    
    return dataset[:split_idx], dataset[split_idx:]

train_features, valid_features = train_test_split(token_ids)
train_labels, valid_labels = train_test_split(sentiments)

# %%
text_batch, labels = next(iter(dataloader(train_features, train_labels, sequence_length=20, batch_size=64)))
model = TextClassifier(len(vocab)+1, 200, 128, 5, dropout=0.)
hidden = model.init_hidden(64)
logps, hidden = model.forward(text_batch, hidden)

# %% [markdown]
# ### Training
# It's time to train the neural network!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = TextClassifier(len(vocab)+1, 1024, 512, 5, lstm_layers=2, dropout=0.2)
model.embedding.weight.data.uniform_(-1, 1)
model.to(device)
# Out:
# TextClassifier(
#   (embedding): Embedding(4538, 1024, padding_idx=0)
#   (lstm): LSTM(1024, 512, num_layers=2, dropout=0.2)
#   (dense): Linear(in_features=512, out_features=5, bias=True)
#   (softmax): LogSoftmax()
# )

# %%
"""
Train your model with dropout. Make sure to clip your gradients.
Print the training loss, validation loss, and validation accuracy for every 100 steps.
"""

epochs = 5
batch_size = 512
learning_rate = 0.001

print_every = 100
clip=5 # gradient clipping
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
model.train()

for epoch in range(epochs):
    print('Starting epoch {}'.format(epoch + 1))
    
    steps = 0
    for text_batch, labels in dataloader(
            train_features, train_labels, batch_size=batch_size, sequence_length=20, shuffle=True):
        steps += 1
        hidden = model.init_hidden(labels.shape[0])
        
        # Set Device
        text_batch, labels = text_batch.to(device), labels.to(device)
        for each in hidden:
            each.to(device)
        
        # TODO Implement: Train Model
        # zero accumulated gradients
        model.zero_grad()
        
        # get the output from the model
        log_probs, hidden = model(text_batch, hidden)
        
        # calculate the loss and perform backprop
        loss = criterion(log_probs, labels)
        loss.backward()
        
        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()  
        if steps % print_every == 0:
            model.eval()
            
            # TODO Implement: Print metrics
            # Get validation loss
            val_losses = []
            
            for text_batch, labels in  dataloader(
                valid_features, valid_labels, batch_size=batch_size, sequence_length=20, shuffle=True):
                
                val_hidden = model.init_hidden(labels.shape[0])
               
                # Set Device
                text_batch, labels = text_batch.to(device), labels.to(device)
                for each in val_hidden:
                    each.to(device)
                    
                log_probs, val_hidden = model(text_batch, val_hidden)
                val_loss = criterion(log_probs, labels)
                
                val_losses.append(val_loss.item())   
            model.train()
            print("Epoch: {}/{}...".format(epoch+1, epochs),
                  "Step: {}...".format(steps),
                  "Loss: {:.6f}...".format(loss.item()),
                  "Val Loss: {:.6f}".format(np.mean(val_losses)))
# Out:
# Starting epoch 1
# Epoch: 1/5... Step: 100... Loss: 0.814699... Val Loss: 0.910664
# Epoch: 1/5... Step: 200... Loss: 0.870165... Val Loss: 0.856218
# Epoch: 1/5... Step: 300... Loss: 0.824360... Val Loss: 0.820349
# Epoch: 1/5... Step: 400... Loss: 0.712975... Val Loss: 0.799239
# Epoch: 1/5... Step: 500... Loss: 0.816003... Val Loss: 0.778452
# Epoch: 1/5... Step: 600... Loss: 0.787944... Val Loss: 0.768398
# Epoch: 1/5... Step: 700... Loss: 0.689226... Val Loss: 0.752717
# Epoch: 1/5... Step: 800... Loss: 0.672838... Val Loss: 0.742484
# Epoch: 1/5... Step: 900... Loss: 0.709993... Val Loss: 0.737308
# Epoch: 1/5... Step: 1000... Loss: 0.698311... Val Loss: 0.729301
# Epoch: 1/5... Step: 1100... Loss: 0.686792... Val Loss: 0.734325
# Epoch: 1/5... Step: 1200... Loss: 0.708511... Val Loss: 0.720658
# Epoch: 1/5... Step: 1300... Loss: 0.681903... Val Loss: 0.720383
# Epoch: 1/5... Step: 1400... Loss: 0.676952... Val Loss: 0.718072
# Starting epoch 2
# Epoch: 2/5... Step: 100... Loss: 0.619496... Val Loss: 0.718166
# Epoch: 2/5... Step: 200... Loss: 0.649647... Val Loss: 0.717406
# Epoch: 2/5... Step: 300... Loss: 0.604788... Val Loss: 0.718694
# Epoch: 2/5... Step: 400... Loss: 0.604437... Val Loss: 0.713706
# Epoch: 2/5... Step: 500... Loss: 0.607432... Val Loss: 0.708877
# Epoch: 2/5... Step: 600... Loss: 0.639623... Val Loss: 0.712222
# Epoch: 2/5... Step: 700... Loss: 0.633491... Val Loss: 0.710780
# Epoch: 2/5... Step: 800... Loss: 0.689905... Val Loss: 0.704732
# Epoch: 2/5... Step: 900... Loss: 0.620531... Val Loss: 0.707143
# Epoch: 2/5... Step: 1000... Loss: 0.617112... Val Loss: 0.705060
# Epoch: 2/5... Step: 1100... Loss: 0.627748... Val Loss: 0.701310
# Epoch: 2/5... Step: 1200... Loss: 0.635040... Val Loss: 0.697911
# Epoch: 2/5... Step: 1300... Loss: 0.621933... Val Loss: 0.699259
# Epoch: 2/5... Step: 1400... Loss: 0.673869... Val Loss: 0.699346
# Starting epoch 3
# Epoch: 3/5... Step: 100... Loss: 0.554295... Val Loss: 0.717956
# Epoch: 3/5... Step: 200... Loss: 0.567269... Val Loss: 0.728617
# Epoch: 3/5... Step: 300... Loss: 0.621798... Val Loss: 0.720841
# Epoch: 3/5... Step: 400... Loss: 0.573778... Val Loss: 0.719076
# Epoch: 3/5... Step: 500... Loss: 0.620836... Val Loss: 0.715226
# Epoch: 3/5... Step: 600... Loss: 0.588355... Val Loss: 0.719279
# Epoch: 3/5... Step: 700... Loss: 0.685147... Val Loss: 0.714252
# Epoch: 3/5... Step: 800... Loss: 0.670785... Val Loss: 0.712001
# Epoch: 3/5... Step: 900... Loss: 0.620275... Val Loss: 0.713098
# Epoch: 3/5... Step: 1000... Loss: 0.711817... Val Loss: 0.710045
# Epoch: 3/5... Step: 1100... Loss: 0.594927... Val Loss: 0.706610
# Epoch: 3/5... Step: 1200... Loss: 0.682528... Val Loss: 0.707969
# Epoch: 3/5... Step: 1300... Loss: 0.607439... Val Loss: 0.701247
# Epoch: 3/5... Step: 1400... Loss: 0.606284... Val Loss: 0.706242
# Starting epoch 4
# Epoch: 4/5... Step: 100... Loss: 0.517506... Val Loss: 0.749245
# Epoch: 4/5... Step: 200... Loss: 0.434301... Val Loss: 0.753357
# Epoch: 4/5... Step: 300... Loss: 0.515830... Val Loss: 0.751724
# Epoch: 4/5... Step: 400... Loss: 0.473459... Val Loss: 0.753691
# Epoch: 4/5... Step: 500... Loss: 0.537288... Val Loss: 0.752097
# Epoch: 4/5... Step: 600... Loss: 0.515423... Val Loss: 0.753465
# Epoch: 4/5... Step: 700... Loss: 0.580532... Val Loss: 0.756033
# Epoch: 4/5... Step: 800... Loss: 0.541951... Val Loss: 0.750992
# Epoch: 4/5... Step: 900... Loss: 0.551193... Val Loss: 0.744943
# Epoch: 4/5... Step: 1000... Loss: 0.552321... Val Loss: 0.742534
# Epoch: 4/5... Step: 1100... Loss: 0.489653... Val Loss: 0.745759
# Epoch: 4/5... Step: 1200... Loss: 0.530519... Val Loss: 0.739374
# Epoch: 4/5... Step: 1300... Loss: 0.533439... Val Loss: 0.738439
# Epoch: 4/5... Step: 1400... Loss: 0.501797... Val Loss: 0.741347
# Starting epoch 5
# Epoch: 5/5... Step: 100... Loss: 0.462900... Val Loss: 0.819058
# Epoch: 5/5... Step: 200... Loss: 0.500237... Val Loss: 0.822269
# Epoch: 5/5... Step: 300... Loss: 0.420237... Val Loss: 0.832341
# Epoch: 5/5... Step: 400... Loss: 0.460353... Val Loss: 0.824721
# Epoch: 5/5... Step: 500... Loss: 0.444814... Val Loss: 0.827960
# Epoch: 5/5... Step: 600... Loss: 0.434460... Val Loss: 0.823508
# Epoch: 5/5... Step: 700... Loss: 0.431166... Val Loss: 0.821900
# Epoch: 5/5... Step: 800... Loss: 0.462707... Val Loss: 0.822121
# Epoch: 5/5... Step: 900... Loss: 0.475218... Val Loss: 0.824143
# Epoch: 5/5... Step: 1000... Loss: 0.448584... Val Loss: 0.815220
# Epoch: 5/5... Step: 1100... Loss: 0.497143... Val Loss: 0.817704
# Epoch: 5/5... Step: 1200... Loss: 0.476439... Val Loss: 0.817852
# Epoch: 5/5... Step: 1300... Loss: 0.538559... Val Loss: 0.814666
# Epoch: 5/5... Step: 1400... Loss: 0.510845... Val Loss: 0.813756

# %% [markdown]
# ## Making Predictions
# ### Prediction
# Okay, now that you have a trained model, try it on some new twits and see if it works appropriately. Remember that for any new text, you'll need to preprocess it first before passing it to the network. Implement the `predict` function to generate the prediction vector from a message.

# %%
def predict(text, model, vocab):
    """ 
    Make a prediction on a single sentence.

    Parameters
    ----------
        text : The string to make a prediction on.
        model : The model to use for making the prediction.
        vocab : Dictionary for word to word ids. The key is the word and the value is the word id.

    Returns
    -------
        pred : Prediction vector
    """    
    
    # TODO Implement
    model.eval()
    tokens = preprocess(text)
    
    # Filter non-vocab words
    tokens = [token for token in tokens if token in vocab]
    # Convert words to ids
    tokens = [vocab[token] for token in tokens]
        
    # Adding a batch dimension
    text_input = torch.from_numpy(np.asarray(torch.FloatTensor(tokens).view(-1,1)))
    # Get the NN output
    hidden = model.init_hidden(1)
    logps, _ = model.forward(text_input, hidden)
    # Take the exponent of the NN output to get a range of 0 to 1 for each label.
    pred = torch.exp(logps)
    
    return pred

# %%
text = "Google is working on self driving cars, I'm bullish on $goog"
model.eval()
model.to("cpu")
predict(text, model, vocab)
# Out:
# tensor([[ 0.0000,  0.0123,  0.0017,  0.9744,  0.0115]])

# %% [markdown]
# ### Questions: What is the prediction of the model? What is the uncertainty of the prediction?
# ** TODO: Answer Question**
#
# The model predicts the 4th label wiht about 97% accuracy.

# %% [markdown]
# Now we have a trained model and we can make predictions. We can use this model to track the sentiments of various stocks by predicting the sentiments of twits as they are coming in. Now we have a stream of twits. For each of those twits, pull out the stocks mentioned in them and keep track of the sentiments. Remember that in the twits, ticker symbols are encoded with a dollar sign as the first character, all caps, and 2-4 letters, like $AAPL. Ideally, you'd want to track the sentiments of the stocks in your universe and use this as a signal in your larger model(s).
#
# ## Testing
# ### Load the Data

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'test_twits.json'), 'r') as f:
    test_data = json.load(f)

# %% [markdown]
# ### Twit Stream

# %%
def twit_stream():
    for twit in test_data['data']:
        yield twit

next(twit_stream())
# Out:
# {'message_body': '$JWN has moved -1.69% on 10-31. Check out the movement and peers at  https://dividendbot.com?s=JWN',
#  'timestamp': '2018-11-01T00:00:05Z'}

# %% [markdown]
# Using the `prediction` function, let's apply it to a stream of twits.

# %%
def score_twits(stream, model, vocab, universe):
    """ 
    Given a stream of twits and a universe of tickers, return sentiment scores for tickers in the universe.
    """
    for twit in stream:

        # Get the message text
        text = twit['message_body']
        symbols = re.findall('\$[A-Z]{2,4}', text)
        score = predict(text, model, vocab)

        for symbol in symbols:
            if symbol in universe:
                yield {'symbol': symbol, 'score': score, 'timestamp': twit['timestamp']}

# %%
universe = {'$BBRY', '$AAPL', '$AMZN', '$BABA', '$YHOO', '$LQMT', '$FB', '$GOOG', '$BBBY', '$JNUG', '$SBUX', '$MU'}
score_stream = score_twits(twit_stream(), model, vocab, universe)

next(score_stream)
# Out:
# {'symbol': '$AAPL',
#  'score': tensor([[ 0.0437,  0.0771,  0.3413,  0.2788,  0.2591]]),
#  'timestamp': '2018-11-01T00:00:18Z'}

# %% [markdown]
# That's it. You have successfully built a model for sentiment analysis!

# %% [markdown]
# ## Submission
# Now that you're done with the project, it's time to submit it. Click the submit button in the bottom right. One of our reviewers will give you feedback on your project with a pass or not passed grade. You can continue to the next section while you wait for feedback.
